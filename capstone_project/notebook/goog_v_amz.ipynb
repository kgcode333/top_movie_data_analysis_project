# %%
# !pip install numpy 
# !pip install pandas
import numpy as np
import pandas as pd


#Useful info for building:
# .keys() == accessing all of the keys/columns in dataframes
#we can slice through a dataframes rows[:]
#.sort_values('Title',kind='mergesort') can organize our data
#when resetting index---.reset_index(drop=True) to dron duplicate indexes
#df.columns -- has no parameters and will show all columns(just like df.keys())
#understand subsetting
#.apply() to apply a function to a specific column
#UDF-- user defined function

# %% [markdown]
# # Google VS. Amazon Job Skills <img src='google-v-amazon.png'>

# %% [markdown]
# ## Reading the CSV files

# %%
# Creating a function to open and read CSV data
# def open_csv(filename, d=','):
#     #define an empty list to store data
#     data = []
    
#     with open(filename, encoding='utf-8') as googData:
#         #use the csv .reader() method to create a python regular list
#         info = csv.reader(googData, delimiter = d)
#         #Loop over the info and append it into the data list
#         for row in info:
#             data.append(row)
#     return data  #gentfromtxt?
# pd.set_option('display.max_columns')

google = pd.read_csv('../files/google_job_skills.csv', sep=',')
amazon = pd.read_csv('../files/amazon_jobs_dataset.csv', sep=',')

# %%
display(google)
# Out:
#      Company                                              Title  \
# 0     Google                       Google Cloud Program Manager
# 1     Google  Supplier Development Engineer (SDE), Cable/Con...
# 2     Google  Data Analyst, Product and Tools Operations, Go...
# 3     Google            Developer Advocate, Partner Engineering
# 4     Google     Program Manager, Audio Visual (AV) Deployments
# ...      ...                                                ...
# 1245  Google                                Global Investigator
# 1246  Google                            Campus Security Manager
# 1247  Google                                 Facilities Manager
# 1248  Google                          Physical Security Manager
# 1249  Google                          Physical Security Manager
#
#                               Category                          Location  \
# 0                   Program Management                         Singapore
# ...

# %%
display(amazon)
# Out:
#       Unnamed: 0                                              Title  \
# 0              0                       Software Development Manager
# 1              1                      Software Development Engineer
# 2              2                      Software Development Engineer
# 3              3         Software Development Engineer - Amazon Lex
# 4              4         Software Development Engineer - Amazon Lex
# ...          ...                                                ...
# 3488        3488                                  Software Engineer
# 3489        3489                      Software Development Engineer
# 3490        3490   Software Development Engineer III - Mar. BR 2012
# 3491        3491  Software Development Engineer in Test II - IMM546
# 3492        3492              Software Development Engineer in Test
#
#                 location       Posting_date  \
# 0       US, WA, Seattle      March  1, 2018
# 1     IN, KA, Bangalore      March  1, 2018
# ...

# %%
# Add a Company column with a value of Amazon and drop the Unnamed column

# %%
#What job categories are available for both Google and Amazon?
# amz_job_cat = amazon.groupby(['Title']).describe()
# display(amz_job_cat)

# %%
# goog_job_cat = google.groupby(['Category']).describe()
# display(goog_job_cat)

# %%
# google_min_qual = google['Title']
# display(google_min_qual)
display(google['Title'][2])
# Out:
# 'Data Analyst, Product and Tools Operations, Google Technical Services'

# %%
# amazon['Company'] = 'Amazon'
# display(amazon)

# %% [markdown]
#   ##
